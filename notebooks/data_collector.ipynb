# %%
import numpy as np
import pandas as pd
from pathlib import Path
#Data Source
import yfinance as yf

#Data viz
import plotly.graph_objs as go

# %%
data = yf.download(tickers='IDFCFIRSTB.NS', period='1d', interval='1m')
#Print data
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.tail()
# Out:
#                                 Open       High        Low      Close  \
# Datetime
# 2023-07-07 15:25:00+05:30  79.650002  79.800003  79.550003  79.800003
# 2023-07-07 15:26:00+05:30  79.750000  79.750000  79.650002  79.750000
# 2023-07-07 15:27:00+05:30  79.750000  79.750000  79.699997  79.699997
# 2023-07-07 15:28:00+05:30  79.699997  79.750000  79.650002  79.699997
# 2023-07-07 15:29:00+05:30  79.699997  79.900002  79.699997  79.699997
#
#                            Adj Close  Volume
# Datetime
# 2023-07-07 15:25:00+05:30  79.800003  242367
# 2023-07-07 15:26:00+05:30  79.750000  110695
# 2023-07-07 15:27:00+05:30  79.699997   99780
# 2023-07-07 15:28:00+05:30  79.699997   74575
# 2023-07-07 15:29:00+05:30  79.699997   94060

# %%
{
    "measurement": ["candlestick", "stock_price"],
    "tags": [{"symbol": "AAPL"}, {"symbol": "GOOG"}],
    "time": [pd.Timestamp.now(), pd.Timestamp.now()],
    "fields": [
        {"open": 150.0, "high": 155.0, "low": 145.0, "close": 148.0, "volume": 1000000},
        {"open": 250.0, "high": 255.0, "low": 245.0, "close": 248.0, "volume": 2000000}
    ]
}

# %%
df.to_csv(Path().absolute() / "notebooks/datasets" / "test_dataset.csv")

# %%
msft = yf.Ticker("IDFCFIRSTB.NS")

# %%
msft.info
# Out:
# {'address1': 'Naman Chambers',
#  'address2': 'C-32, G-Block Bandra-Kurla Complex Bandra (East)',
#  'city': 'Mumbai',
#  'zip': '400051',
#  'country': 'India',
#  'phone': '91 22 7132 5500',
#  'fax': '91 22 2654 0354',
#  'website': 'https://www.idfcfirstbank.com',
#  'industry': 'Banks—Regional',
#  'industryDisp': 'Banks—Regional',
#  'sector': 'Financial Services',
# ...

# %%
# get historical market data
hist = msft.history(period="1d", interval="1m",
                start=None, end=None, prepost=False, actions=True,
                auto_adjust=True, back_adjust=False, repair=True, keepna=False,
                proxy=None, rounding=False, timeout=10,
                raise_errors=False)
hist
# Out:
#                                 Open       High        Low      Close  Volume  \
# Datetime
# 2023-07-07 09:15:00+05:30  80.449997  80.449997  80.000000  80.250000       0
# 2023-07-07 09:16:00+05:30  80.300003  80.300003  80.099998  80.250000  293733
# 2023-07-07 09:17:00+05:30  80.199997  80.300003  80.099998  80.300003  238919
# 2023-07-07 09:18:00+05:30  80.300003  80.449997  80.199997  80.400002  213057
# 2023-07-07 09:19:00+05:30  80.400002  80.449997  80.300003  80.300003  171577
# ...                              ...        ...        ...        ...     ...
# 2023-07-07 15:25:00+05:30  79.650002  79.800003  79.550003  79.800003  242367
# 2023-07-07 15:26:00+05:30  79.750000  79.750000  79.650002  79.750000  110695
# 2023-07-07 15:27:00+05:30  79.750000  79.750000  79.699997  79.699997   99780
# 2023-07-07 15:28:00+05:30  79.699997  79.750000  79.650002  79.699997   74575
# 2023-07-07 15:29:00+05:30  79.699997  79.900002  79.699997  79.699997   94060
#
# ...

# %%
type(hist)
# Out:
# pandas.core.frame.DataFrame

# %%
msft.history_metadata
# Out:
# {'currency': 'INR',
#  'symbol': 'IDFCFIRSTB.NS',
#  'exchangeName': 'NSI',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 1446781500,
#  'regularMarketTime': 1688723999,
#  'gmtoffset': 19800,
#  'timezone': 'IST',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'regularMarketPrice': 79.7,
#  'chartPreviousClose': 73.6,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'IST',
#    'start': 1688701500,
#    'end': 1688701500,
#    'gmtoffset': 19800},
#   'regular': {'timezone': 'IST',
#    'start': 1688701500,
#    'end': 1688724000,
#    'gmtoffset': 19800},
#   'post': {'timezone': 'IST',
#    'start': 1688724000,
#    'end': 1688724000,
#    'gmtoffset': 19800}},
#  'dataGranularity': '1d',
#  'range': '1mo',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
# show actions (dividends, splits, capital gains)
[msft.actions,
msft.dividends,
msft.splits,
msft.capital_gains]
# Out:
# [Empty DataFrame
#  Columns: [Dividends, Stock Splits]
#  Index: [],
#  Series([], Name: Dividends, dtype: float64),
#  Series([], Name: Stock Splits, dtype: float64),
#  []]

# %%
# show share count
msft.get_shares_full(start="2022-01-01", end=None)
# Out:
# 2022-01-27 00:00:00+05:30    6216690176
# 2022-02-12 00:00:00+05:30    6216690176
# 2022-02-15 00:00:00+05:30    6592809984
# 2022-02-16 00:00:00+05:30    6216690176
# 2022-02-22 00:00:00+05:30    6217650176
#                                 ...
# 2023-06-20 00:00:00+05:30    6658039808
# 2023-06-22 00:00:00+05:30    6625439744
# 2023-06-24 00:00:00+05:30    6628179968
# 2023-06-28 00:00:00+05:30    6670810112
# 2023-06-29 00:00:00+05:30    6628179968
# Length: 75, dtype: int64

# %%
# show financials:
# - income statement
msft.income_stmt
# Out:
#                                                         2023-03-31  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.254088
# Total Unusual Items                                            0.0
# Total Unusual Items Excluding Goodwill                         0.0
# Net Income From Continuing Operation Net Minori...   24849300000.0
# Reconciled Depreciation                               4349900000.0
# Net Interest Income                                 126371700000.0
# Interest Expense                                    100906400000.0
# Interest Income                                     227278100000.0
# Normalized Income                                    24849300000.0
# Net Income From Continuing And Discontinued Ope...   24849300000.0
# Diluted Average Shares                                6339107143.0
# Basic Average Shares                                  6243542714.0
# ...

# %%
msft.quarterly_income_stmt
# Out:
#                                                        2023-03-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                        0.25427
# Total Unusual Items                                           0.0
# Total Unusual Items Excluding Goodwill                        0.0
# Net Income From Continuing Operation Net Minori...   8161200000.0
# Net Interest Income                                 35973600000.0
# Interest Expense                                    28270600000.0
# Interest Income                                     64244200000.0
# Normalized Income                                    8161200000.0
# Net Income From Continuing And Discontinued Ope...   8161200000.0
# Diluted Average Shares                                        NaN
# Basic Average Shares                                          NaN
# Diluted EPS                                                   NaN
# ...

# %%
# - balance sheet
msft.balance_sheet
# Out:
#                                                   2023-03-31       2022-03-31  \
# Ordinary Shares Number                          6618121816.0     6217708310.0
# Share Issued                                    6618121816.0     6217708310.0
# Net Debt                                      434334100000.0   367525670000.0
# Total Debt                                    572120900000.0   540720097000.0
# Tangible Book Value                           257078900000.0   210821196000.0
# Invested Capital                              830596400000.0   751541293000.0
# Net Tangible Assets                           257078900000.0   210821196000.0
# Common Stock Equity                           258475500000.0   210821196000.0
# Total Capitalization                          830596400000.0   751541293000.0
# Total Equity Gross Minority Interest          258475500000.0   210821196000.0
# Minority Interest                                        0.0              0.0
# ...

# %%
msft.quarterly_balance_sheet
# Out:
#                                                   2023-03-31       2022-09-30
# Ordinary Shares Number                          6618121816.0     6221337487.0
# Share Issued                                    6618121816.0     6221337487.0
# Net Debt                                      434334100000.0   417959000000.0
# Total Debt                                    572120900000.0   566430100000.0
# Tangible Book Value                           257078900000.0   220518800000.0
# Invested Capital                              830596400000.0   786948900000.0
# Net Tangible Assets                           257078900000.0   220518800000.0
# Common Stock Equity                           258475500000.0   220518800000.0
# Total Capitalization                          830596400000.0   786948900000.0
# Total Equity Gross Minority Interest          258475500000.0   220518800000.0
# Minority Interest                                        0.0              NaN
# ...

# %%
# - cash flow statement
msft.quarterly_cashflow
msft.cashflow
# Out:
#                                                  2023-03-31      2022-03-31  \
# Free Cash Flow                                23749100000.0   21972867000.0
# Repayment Of Debt                                       NaN             NaN
# Issuance Of Debt                              27494900000.0   71765139000.0
# Issuance Of Capital Stock                     22595500000.0   30340750000.0
# Capital Expenditure                          -11881000000.0   -4818448000.0
# End Cash Position                            137786800000.0  157023727000.0
# Other Cash Adjustment Outside Changein Cash             NaN       -100000.0
# Beginning Cash Position                      157023700000.0   57731245000.0
# Changes In Cash                              -19236900000.0   99292482000.0
# Financing Cash Flow                           65090400000.0  102105889000.0
# Net Other Financing Charges                   15000000000.0    1500000000.0
# ...

# %%
# show holders
msft.major_holders
msft.institutional_holders
msft.mutualfund_holders

# %%
msft.major_holders
# Out:
#         0                                      1
# 0  44.69%        % of Shares Held by All Insider
# 1  22.37%       % of Shares Held by Institutions
# 2  40.43%        % of Float Held by Institutions
# 3      72  Number of Institutions Holding Shares

# %%
msft.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2024-04-27 16:00:00+05:30           NaN           NaN          NaN
# 2024-01-19 16:00:00+05:30           NaN           NaN          NaN
# 2023-10-20 16:00:00+05:30           NaN           NaN          NaN
# 2023-07-28 16:00:00+05:30           NaN           NaN          NaN
# 2023-04-29 15:00:00+05:30          1.01          1.28       0.2673

# %%
msft.isin
msft.options
msft.news
# Out:
# [{'uuid': '9ae8db58-b45f-3770-bc89-c6fa2dbf7534',
#   'title': 'Prime Day Security Camera Deals (2023): Early Ring, Blink, Google Nest & More Sales Identified by Retail Replay',
#   'publisher': 'Business Wire',
#   'link': 'https://finance.yahoo.com/news/prime-day-security-camera-deals-154500677.html',
#   'providerPublishTime': 1688831100,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/FOVZ8kbMSnmz56_kc1OJEg--~B/aD0yNjk7dz00ODA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/business-wire.com/6e1d257e5f848b1dd6fe43ea63e1ae68',
#      'width': 480,
#      'height': 269,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/fsPjqhGKm3MlnCd_CtBnAg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/business-wire.com/6e1d257e5f848b1dd6fe43ea63e1ae68',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': 'a6516344-ef75-3631-802b-3d7ad95b4dce',
# ...

# %%
msft.splits
# Out:
# Series([], Name: Stock Splits, dtype: float64)
